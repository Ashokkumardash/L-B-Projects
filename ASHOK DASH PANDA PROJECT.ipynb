# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Ashok Dsa\Downloads\archive\AnimeWorld.csv")

# %%
df
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...

# %%
df.head()
# Out:
#                                                Anime  \
# 0   Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                               Kanojo, Okarishimasu
# 2                             The God of High School
# 3  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                     Enen no Shouboutai: Ni no Shou
#
#                                              Genre  \
# 0                 ['Drama', 'Fantasy', 'Suspense']
# 1                            ['Comedy', 'Romance']
# 2  ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                            ['Action', 'Fantasy']
# 4                       ['Action', 'Supernatural']
#
#                                          Description             Studio  \
# 0  A reunion that was supposed to spell the arriv...          White Fox
# 1  Kazuya Kinoshita is a 20-year-old college stud...  TMS Entertainment
# 2  The "God of High School" tournament has begun,...              MAPPA
# ...

# %%
df.head(12)
# Out:
#                                                 Anime  \
# 0    Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                Kanojo, Okarishimasu
# 2                              The God of High School
# 3   Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                      Enen no Shouboutai: Ni no Shou
# 5   Yahari Ore no Seishun Love Comedy wa Machigatt...
# 6                                     Great Pretender
# 7   Sword Art Online: Alicization - War of Underwo...
# 8                             Uzaki-chan wa Asobitai!
# 9                                          Deca-Dence
# 10                         Monster Musume no Oishasan
# 11                      Peter Grill to Kenja no Jikan
#
#                                               Genre  \
# 0                  ['Drama', 'Fantasy', 'Suspense']
# 1                             ['Comedy', 'Romance']
# 2   ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# ...

# %%
df.tail()
# Out:
#                                         Anime          Genre  \
# 2976                 Estab-Life: Great Escape         Sci-Fi
# 2977        Meitantei Conan: Zero no Tea Time  Slice of Life
# 2978  Yatogame-chan Kansatsu Nikki Yonsatsume         Comedy
# 2979                            Jantama Pong☆         Comedy
# 2980                    Kenda Master Ken (TV)         Comedy
#
#                                             Description             Studio  \
# 2976  The distant future. After reaching its peak, E...   Polygon Pictures
# 2977  Anime adaptation of the spin-off manga Meitant...  TMS Entertainment
# 2978     Fourth season of Yatogame-chan Kansatsu Nikki.   Creators in Pack
# 2979  Based on characters from the free to play onli...      Scooter Films
# 2980  Ken Tamaki defeats corrupt organizations and e...   Studio Kingyoiro
#
#              Year  Rating
# 2976  Apr 6, 2022     NaN
# 2977  Apr 5, 2022     NaN
# 2978  Apr 9, 2022     NaN
# 2979  Apr 9, 2022     NaN
# ...

# %%
df.tail(12)
# Out:
#                                         Anime                  Genre  \
# 2969                              Healer Girl                     []
# 2970                        Gunjou no Fanfare                 Sports
# 2971                          Shin Ikkitousen    ['Action', 'Ecchi']
# 2972                 Build Divide: Code White                Fantasy
# 2973                                  Onipan!  ['Comedy', 'Fantasy']
# 2974                        Kaginado Season 2                 Comedy
# 2975                     Kyoukai Senki Part 2   ['Action', 'Sci-Fi']
# 2976                 Estab-Life: Great Escape                 Sci-Fi
# 2977        Meitantei Conan: Zero no Tea Time          Slice of Life
# 2978  Yatogame-chan Kansatsu Nikki Yonsatsume                 Comedy
# 2979                            Jantama Pong☆                 Comedy
# 2980                    Kenda Master Ken (TV)                 Comedy
#
#                                             Description  \
# ...

# %%
df.columns
# Out:
# Index(['Anime', 'Genre', 'Description', 'Studio', 'Year', 'Rating'], dtype='object')

# %%
df.shape
# Out:
# (2981, 6)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2981 entries, 0 to 2980
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Anime        2981 non-null   object
#  1   Genre        2981 non-null   object
#  2   Description  2981 non-null   object
#  3   Studio       2895 non-null   object
#  4   Year         2981 non-null   object
#  5   Rating       276 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 139.9+ KB

# %%
df.dtypes
# Out:
# Anime           object
# Genre           object
# Description     object
# Studio          object
# Year            object
# Rating         float64
# dtype: object

# %%
df['Anime']
# Out:
# 0        Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                    Kanojo, Okarishimasu
# 2                                  The God of High School
# 3       Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                          Enen no Shouboutai: Ni no Shou
#                               ...
# 2976                             Estab-Life: Great Escape
# 2977                    Meitantei Conan: Zero no Tea Time
# 2978              Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                        Jantama Pong☆
# 2980                                Kenda Master Ken (TV)
# Name: Anime, Length: 2981, dtype: object

# %%
df['Anime'].unique
# Out:
# <bound method Series.unique of 0        Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                    Kanojo, Okarishimasu
# 2                                  The God of High School
# 3       Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                          Enen no Shouboutai: Ni no Shou
#                               ...
# 2976                             Estab-Life: Great Escape
# 2977                    Meitantei Conan: Zero no Tea Time
# 2978              Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                        Jantama Pong☆
# 2980                                Kenda Master Ken (TV)
# Name: Anime, Length: 2981, dtype: object>

# %%
df['Description']
# Out:
# 0       A reunion that was supposed to spell the arriv...
# 1       Kazuya Kinoshita is a 20-year-old college stud...
# 2       The "God of High School" tournament has begun,...
# 3       In the distant past, a war between humans and ...
# 4       After his confrontation in the Nether with his...
#                               ...
# 2976    The distant future. After reaching its peak, E...
# 2977    Anime adaptation of the spin-off manga Meitant...
# 2978       Fourth season of Yatogame-chan Kansatsu Nikki.
# 2979    Based on characters from the free to play onli...
# 2980    Ken Tamaki defeats corrupt organizations and e...
# Name: Description, Length: 2981, dtype: object

# %%
df['Description'].unique
# Out:
# <bound method Series.unique of 0       A reunion that was supposed to spell the arriv...
# 1       Kazuya Kinoshita is a 20-year-old college stud...
# 2       The "God of High School" tournament has begun,...
# 3       In the distant past, a war between humans and ...
# 4       After his confrontation in the Nether with his...
#                               ...
# 2976    The distant future. After reaching its peak, E...
# 2977    Anime adaptation of the spin-off manga Meitant...
# 2978       Fourth season of Yatogame-chan Kansatsu Nikki.
# 2979    Based on characters from the free to play onli...
# 2980    Ken Tamaki defeats corrupt organizations and e...
# Name: Description, Length: 2981, dtype: object>

# %%
df[['Anime','Description']]
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                             Description
# 0     A reunion that was supposed to spell the arriv...
# 1     Kazuya Kinoshita is a 20-year-old college stud...
# 2     The "God of High School" tournament has begun,...
# 3     In the distant past, a war between humans and ...
# ...

# %%
df[['Anime','Description','Genre']]
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                             Description  \
# 0     A reunion that was supposed to spell the arriv...
# 1     Kazuya Kinoshita is a 20-year-old college stud...
# 2     The "God of High School" tournament has begun,...
# 3     In the distant past, a war between humans and ...
# ...

# %%
df
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...

# %%
df.isnull()
# Out:
#       Anime  Genre  Description  Studio   Year  Rating
# 0     False  False        False   False  False   False
# 1     False  False        False   False  False    True
# 2     False  False        False   False  False    True
# 3     False  False        False   False  False    True
# 4     False  False        False   False  False    True
# ...     ...    ...          ...     ...    ...     ...
# 2976  False  False        False   False  False    True
# 2977  False  False        False   False  False    True
# 2978  False  False        False   False  False    True
# 2979  False  False        False   False  False    True
# 2980  False  False        False   False  False    True
#
# [2981 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Anime             0
# Genre             0
# Description       0
# Studio           86
# Year              0
# Rating         2705
# dtype: int64

# %%
df[df['Anime']=='The God of High School']
# Out:
#                     Anime                                            Genre  \
# 2  The God of High School  ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
#
#                                          Description Studio         Year  \
# 2  The "God of High School" tournament has begun,...  MAPPA  Jul 6, 2020
#
#    Rating
# 2     NaN

# %%
df.select_dtypes(include='object')
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...

# %%
df.drop_duplicates()
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...

# %%
df.drop(['Rating'],axis=1)
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...

# %%
df.drop(df.columns[[2,3,4,5]],axis=1)
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...

# %%
df
# Out:
#                                                   Anime  \
# 0      Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                  Kanojo, Okarishimasu
# 2                                The God of High School
# 3     Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                        Enen no Shouboutai: Ni no Shou
# ...                                                 ...
# 2976                           Estab-Life: Great Escape
# 2977                  Meitantei Conan: Zero no Tea Time
# 2978            Yatogame-chan Kansatsu Nikki Yonsatsume
# 2979                                      Jantama Pong☆
# 2980                              Kenda Master Ken (TV)
#
#                                                 Genre  \
# 0                    ['Drama', 'Fantasy', 'Suspense']
# 1                               ['Comedy', 'Romance']
# 2     ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                               ['Action', 'Fantasy']
# ...
